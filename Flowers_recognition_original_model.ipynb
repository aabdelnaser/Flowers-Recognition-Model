# %%
# data visualisation and manipulation
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns


#model selection
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score,precision_score,recall_score,confusion_matrix,roc_curve,roc_auc_score
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import LabelEncoder

#preprocess.
from keras.preprocessing.image import ImageDataGenerator

from keras.models import Sequential
from keras.layers import Dense
from tensorflow.keras.optimizers import Adam,SGD,Adagrad,Adadelta,RMSprop
from tensorflow.keras.utils import to_categorical


# specifically for cnn
from keras.layers import Dropout, Flatten,Activation
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization

import tensorflow as tf
import random as rn


#  manipulating zipped images and getting numpy arrays of pixel values of images.
import cv2                  
import numpy as np  
from tqdm import tqdm
import os                   
from random import shuffle  
from zipfile import ZipFile
from PIL import Image

# %%
X=[]
Z=[]
IMG_SIZE=150
FLOWER_DAISY_DIR='/content/daisy'
FLOWER_DANDI_DIR='/content/dandelion'
FLOWER_ROSE_DIR='/content/rose'

# %%
def assign_label(img,flower_type):
    return flower_type
    
def make_train_data(flower_type,DIR):
    for img in tqdm(os.listdir(DIR)):
        label=assign_label(img,flower_type)
        path = os.path.join(DIR,img)
        img = cv2.imread(path,cv2.IMREAD_COLOR)
        img = cv2.resize(img, (IMG_SIZE,IMG_SIZE))
        
        X.append(np.array(img))
        Z.append(str(label))

# %%
make_train_data('Daisy',FLOWER_DAISY_DIR)
print(len(X))
# Out:
# 100%|██████████| 764/764 [00:01<00:00, 385.73it/s]
# 764

# %%
make_train_data('Dandelion',FLOWER_DANDI_DIR)
print(len(X))
# Out:
# 100%|██████████| 631/631 [00:01<00:00, 345.59it/s]
# 1395

# %%
make_train_data('Rose',FLOWER_ROSE_DIR)
print(len(X))
# Out:
# 100%|██████████| 784/784 [00:01<00:00, 398.80it/s]
# 2179

# %%
fig,ax=plt.subplots(5,2)
fig.set_size_inches(15,15)
for i in range(5):
    for j in range (2):
        l=rn.randint(0,len(Z))
        ax[i,j].imshow(X[l])
        ax[i,j].set_title('Flower: '+Z[l])

plt.tight_layout()

# %%
le=LabelEncoder()
Y=le.fit_transform(Z)
Y=to_categorical(Y,5)
X=np.array(X)
X=X/255

# %%
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.25,random_state=42)

# %%
batch_size=128
epochs=50

from keras.callbacks import ReduceLROnPlateau
red_lr= ReduceLROnPlateau(monitor='val_acc',patience=3,verbose=1,factor=0.1)

# %%
model = Sequential()
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same',activation ='relu', input_shape = (150,150,3)))
model.add(MaxPooling2D(pool_size=(2,2)))


model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same',activation ='relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))
 

model.add(Conv2D(filters =96, kernel_size = (3,3),padding = 'Same',activation ='relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))

model.add(Conv2D(filters = 96, kernel_size = (3,3),padding = 'Same',activation ='relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dense(5, activation = "softmax"))

# %%
model.compile(optimizer=Adam(learning_rate=0.001),loss='categorical_crossentropy',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 150, 150, 32)      2432
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 75, 75, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 75, 75, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 37, 37, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 37, 37, 96)        55392
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 18, 18, 96)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 18, 18, 96)        83040
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 9, 9, 96)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 7776)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               3981824
# _________________________________________________________________
# activation (Activation)      (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 2565
# =================================================================
# Total params: 4,143,749
# Trainable params: 4,143,749
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(x_train,y_train,epochs=epochs,batch_size=batch_size,validation_data = (x_test,y_test))
# Out:
# Epoch 1/50
# 13/13 [==============================] - 88s 7s/step - loss: 1.2172 - accuracy: 0.3140 - val_loss: 1.0986 - val_accuracy: 0.3358
# Epoch 2/50
# 13/13 [==============================] - 86s 7s/step - loss: 0.9926 - accuracy: 0.4841 - val_loss: 0.8732 - val_accuracy: 0.4972
# Epoch 3/50
# 13/13 [==============================] - 86s 7s/step - loss: 0.8385 - accuracy: 0.5930 - val_loss: 0.7129 - val_accuracy: 0.7046
# Epoch 4/50
# 13/13 [==============================] - 86s 7s/step - loss: 0.7811 - accuracy: 0.6610 - val_loss: 0.6735 - val_accuracy: 0.6972
# Epoch 5/50
# 13/13 [==============================] - 87s 7s/step - loss: 0.6994 - accuracy: 0.7007 - val_loss: 0.6210 - val_accuracy: 0.7358
# Epoch 6/50
# 13/13 [==============================] - 86s 7s/step - loss: 0.6684 - accuracy: 0.7191 - val_loss: 0.5548 - val_accuracy: 0.7651
# Epoch 7/50
# 13/13 [==============================] - 86s 7s/step - loss: 0.6144 - accuracy: 0.7485 - val_loss: 0.5618 - val_accuracy: 0.7688
# Epoch 8/50
# 13/13 [==============================] - 86s 7s/step - loss: 0.5426 - accuracy: 0.7815 - val_loss: 0.6004 - val_accuracy: 0.7394
# Epoch 9/50
# 13/13 [==============================] - 86s 7s/step - loss: 0.5642 - accuracy: 0.7821 - val_loss: 0.5253 - val_accuracy: 0.7945
# Epoch 10/50
# 13/13 [==============================] - 86s 7s/step - loss: 0.4887 - accuracy: 0.8078 - val_loss: 0.4977 - val_accuracy: 0.7982
# Epoch 11/50
# 13/13 [==============================] - 86s 7s/step - loss: 0.4384 - accuracy: 0.8152 - val_loss: 0.4710 - val_accuracy: 0.8110
# Epoch 12/50
# 13/13 [==============================] - 86s 7s/step - loss: 0.3813 - accuracy: 0.8543 - val_loss: 0.4841 - val_accuracy: 0.7982
# Epoch 13/50
# 13/13 [==============================] - 86s 7s/step - loss: 0.3342 - accuracy: 0.8672 - val_loss: 0.4941 - val_accuracy: 0.8165
# Epoch 14/50
# 13/13 [==============================] - 86s 7s/step - loss: 0.2974 - accuracy: 0.8794 - val_loss: 0.5018 - val_accuracy: 0.8055
# Epoch 15/50
# 13/13 [==============================] - 86s 7s/step - loss: 0.2737 - accuracy: 0.8972 - val_loss: 0.5432 - val_accuracy: 0.7927
# Epoch 16/50
# 13/13 [==============================] - 86s 7s/step - loss: 0.2349 - accuracy: 0.9119 - val_loss: 0.6028 - val_accuracy: 0.7890
# Epoch 17/50
# 13/13 [==============================] - 86s 7s/step - loss: 0.2239 - accuracy: 0.9137 - val_loss: 0.5330 - val_accuracy: 0.7927
# Epoch 18/50
# 13/13 [==============================] - 86s 7s/step - loss: 0.1684 - accuracy: 0.9400 - val_loss: 0.6622 - val_accuracy: 0.7872
# Epoch 19/50
# 13/13 [==============================] - 86s 7s/step - loss: 0.1117 - accuracy: 0.9651 - val_loss: 0.6811 - val_accuracy: 0.7982
# Epoch 20/50
# 13/13 [==============================] - 86s 7s/step - loss: 0.1108 - accuracy: 0.9651 - val_loss: 0.9339 - val_accuracy: 0.7670
# Epoch 21/50
# 13/13 [==============================] - 88s 7s/step - loss: 0.1183 - accuracy: 0.9565 - val_loss: 0.7134 - val_accuracy: 0.7780
# Epoch 22/50
# 13/13 [==============================] - 87s 7s/step - loss: 0.0749 - accuracy: 0.9780 - val_loss: 0.8008 - val_accuracy: 0.7835
# Epoch 23/50
# 13/13 [==============================] - 88s 7s/step - loss: 0.0393 - accuracy: 0.9890 - val_loss: 0.8724 - val_accuracy: 0.7872
# Epoch 24/50
# 13/13 [==============================] - 87s 7s/step - loss: 0.0307 - accuracy: 0.9927 - val_loss: 1.0142 - val_accuracy: 0.7890
# Epoch 25/50
# 13/13 [==============================] - 87s 7s/step - loss: 0.0258 - accuracy: 0.9933 - val_loss: 1.0087 - val_accuracy: 0.8000
# Epoch 26/50
# 13/13 [==============================] - 87s 7s/step - loss: 0.0200 - accuracy: 0.9957 - val_loss: 1.0964 - val_accuracy: 0.7908
# Epoch 27/50
# 13/13 [==============================] - 88s 7s/step - loss: 0.0227 - accuracy: 0.9945 - val_loss: 1.0451 - val_accuracy: 0.8000
# Epoch 28/50
# 13/13 [==============================] - 90s 7s/step - loss: 0.0119 - accuracy: 0.9963 - val_loss: 1.0611 - val_accuracy: 0.8000
# Epoch 29/50
# 13/13 [==============================] - 88s 7s/step - loss: 0.0098 - accuracy: 0.9976 - val_loss: 1.1286 - val_accuracy: 0.8110
# Epoch 30/50
# 13/13 [==============================] - 88s 7s/step - loss: 0.0058 - accuracy: 0.9994 - val_loss: 1.2004 - val_accuracy: 0.7982
# Epoch 31/50
# 13/13 [==============================] - 88s 7s/step - loss: 0.0040 - accuracy: 0.9994 - val_loss: 1.1721 - val_accuracy: 0.7982
# Epoch 32/50
# 13/13 [==============================] - 88s 7s/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 1.2333 - val_accuracy: 0.8000
# Epoch 33/50
# 13/13 [==============================] - 88s 7s/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 1.1768 - val_accuracy: 0.7945
# Epoch 34/50
# 13/13 [==============================] - 88s 7s/step - loss: 8.2446e-04 - accuracy: 1.0000 - val_loss: 1.2182 - val_accuracy: 0.8037
# Epoch 35/50
# 13/13 [==============================] - 92s 7s/step - loss: 5.4097e-04 - accuracy: 1.0000 - val_loss: 1.2343 - val_accuracy: 0.7982
# Epoch 36/50
# 13/13 [==============================] - 90s 7s/step - loss: 4.5056e-04 - accuracy: 1.0000 - val_loss: 1.2571 - val_accuracy: 0.7982
# Epoch 37/50
# 13/13 [==============================] - 89s 7s/step - loss: 3.7392e-04 - accuracy: 1.0000 - val_loss: 1.2735 - val_accuracy: 0.8000
# Epoch 38/50
# 13/13 [==============================] - 89s 7s/step - loss: 3.2217e-04 - accuracy: 1.0000 - val_loss: 1.2843 - val_accuracy: 0.7982
# Epoch 39/50
# 13/13 [==============================] - 89s 7s/step - loss: 2.8765e-04 - accuracy: 1.0000 - val_loss: 1.3023 - val_accuracy: 0.7963
# Epoch 40/50
# 13/13 [==============================] - 89s 7s/step - loss: 2.6187e-04 - accuracy: 1.0000 - val_loss: 1.3148 - val_accuracy: 0.7982
# Epoch 41/50
# 13/13 [==============================] - 89s 7s/step - loss: 2.4232e-04 - accuracy: 1.0000 - val_loss: 1.3272 - val_accuracy: 0.7982
# Epoch 42/50
# 13/13 [==============================] - 89s 7s/step - loss: 2.1947e-04 - accuracy: 1.0000 - val_loss: 1.3401 - val_accuracy: 0.8000
# Epoch 43/50
# 13/13 [==============================] - 89s 7s/step - loss: 2.0434e-04 - accuracy: 1.0000 - val_loss: 1.3518 - val_accuracy: 0.8000
# Epoch 44/50
# 13/13 [==============================] - 89s 7s/step - loss: 1.9096e-04 - accuracy: 1.0000 - val_loss: 1.3625 - val_accuracy: 0.7982
# Epoch 45/50
# 13/13 [==============================] - 89s 7s/step - loss: 1.7651e-04 - accuracy: 1.0000 - val_loss: 1.3710 - val_accuracy: 0.7982
# Epoch 46/50
# 13/13 [==============================] - 89s 7s/step - loss: 1.6715e-04 - accuracy: 1.0000 - val_loss: 1.3836 - val_accuracy: 0.7963
# Epoch 47/50
# 13/13 [==============================] - 89s 7s/step - loss: 1.5537e-04 - accuracy: 1.0000 - val_loss: 1.3921 - val_accuracy: 0.8000
# Epoch 48/50
# 13/13 [==============================] - 88s 7s/step - loss: 1.4740e-04 - accuracy: 1.0000 - val_loss: 1.4040 - val_accuracy: 0.7982
# Epoch 49/50
# 13/13 [==============================] - 89s 7s/step - loss: 1.3661e-04 - accuracy: 1.0000 - val_loss: 1.4170 - val_accuracy: 0.7963
# Epoch 50/50
# 13/13 [==============================] - 89s 7s/step - loss: 1.2820e-04 - accuracy: 1.0000 - val_loss: 1.4238 - val_accuracy: 0.8000

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'test'])
plt.show()

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'test'])
plt.show()
